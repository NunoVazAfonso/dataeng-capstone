# %%
import requests
import pandas as pd

# %%
vaccination_url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.json'
covid_url = 'https://covid19.who.int/WHO-COVID-19-global-data.csv'

# %%
vaccinations_json = requests.get(vaccination_url).json()

daily_vaccinations = pd.json_normalize( vaccinations_json 
                  ,meta=['country', 'iso_code']
                  ,record_path= 'data' )

# %%
daily_vaccinations
# Out:
#             date  total_vaccinations  people_vaccinated  \
# 0     2021-01-10                 0.0                0.0
# 1     2021-01-11                 NaN                NaN
# 2     2021-01-12               128.0              128.0
# 3     2021-01-13               188.0              188.0
# 4     2021-01-14               266.0              266.0
# ...          ...                 ...                ...
# 5989  2021-03-09             35761.0            35761.0
# 5990  2021-03-10             35901.0            35901.0
# 5991  2021-03-11             36019.0            36019.0
# 5992  2021-03-12             36283.0            36283.0
# 5993  2021-03-13             36359.0            36359.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                           0.00
# 1                                NaN                            NaN
# 2                               0.00                           0.00
# 3                               0.01                           0.01
# 4                               0.01                           0.01
# ...                              ...                            ...
# 5989                            0.24                           0.24
# 5990                            0.24                           0.24
# 5991                            0.24                           0.24
# 5992                            0.24                           0.24
# 5993                            0.24                           0.24
#
#       daily_vaccinations  daily_vaccinations_per_million  \
# 0                    NaN                             NaN
# 1                   64.0                            22.0
# 2                   64.0                            22.0
# 3                   63.0                            22.0
# 4                   66.0                            23.0
# ...                  ...                             ...
# 5989              1526.0                           103.0
# 5990              1133.0                            76.0
# 5991               766.0                            52.0
# 5992               708.0                            48.0
# 5993               621.0                            42.0
#
#       daily_vaccinations_raw  people_fully_vaccinated  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                       60.0                      NaN
# 4                       78.0                      NaN
# ...                      ...                      ...
# 5989                   243.0                      NaN
# 5990                   140.0                      NaN
# 5991                   118.0                      NaN
# 5992                   264.0                      NaN
# 5993                    76.0                      NaN
#
#       people_fully_vaccinated_per_hundred   country iso_code
# 0                                     NaN   Albania      ALB
# 1                                     NaN   Albania      ALB
# 2                                     NaN   Albania      ALB
# 3                                     NaN   Albania      ALB
# 4                                     NaN   Albania      ALB
# ...                                   ...       ...      ...
# 5989                                  NaN  Zimbabwe      ZWE
# 5990                                  NaN  Zimbabwe      ZWE
# 5991                                  NaN  Zimbabwe      ZWE
# 5992                                  NaN  Zimbabwe      ZWE
# 5993                                  NaN  Zimbabwe      ZWE
#
# [5994 rows x 12 columns]

# %%
#row count
daily_vaccinations.shape[0]
# Out:
# 5784

# %% [markdown]
# Test Count: 5.784

# %%
# daily data on COVID cases and deaths
cases_df = pd.read_csv( covid_url )
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 102544    2021-03-07           ZW     Zimbabwe       AFRO         12
# 102545    2021-03-08           ZW     Zimbabwe       AFRO         11
# 102546    2021-03-09           ZW     Zimbabwe       AFRO         18
# 102547    2021-03-10           ZW     Zimbabwe       AFRO         32
# 102548    2021-03-11           ZW     Zimbabwe       AFRO         20
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# 1                      0           0                  0
# 2                      0           0                  0
# 3                      0           0                  0
# 4                      0           0                  0
# ...                  ...         ...                ...
# 102544             36260           1               1485
# 102545             36271           0               1485
# 102546             36289           2               1487
# 102547             36321           2               1489
# 102548             36341           0               1489
#
# [102549 rows x 8 columns]

# %%
#row count
cases_df.shape[0]
# Out:
# 102549

# %% [markdown]
# Test count: 102.549

# %% [markdown]
# #### Countries dim mapper

# %%
# !pip install pycountry

# %%
import pycountry

# %%
country_objects = pycountry.countries.objects

countries = []    
[ countries.append( {'name': country.name , 'alpha_2': country.alpha_2, 'alpha_3': country.alpha_3 } ) 
     for country in country_objects ]

countries_df = pd.DataFrame( countries )

# %%
countries_df
# Out:
#               name alpha_2 alpha_3
# 0            Aruba      AW     ABW
# 1      Afghanistan      AF     AFG
# 2           Angola      AO     AGO
# 3         Anguilla      AI     AIA
# 4    Åland Islands      AX     ALA
# ..             ...     ...     ...
# 244          Samoa      WS     WSM
# 245          Yemen      YE     YEM
# 246   South Africa      ZA     ZAF
# 247         Zambia      ZM     ZMB
# 248       Zimbabwe      ZW     ZWE
#
# [249 rows x 3 columns]

# %%
tables = [
    {'name': 'covid', 'ke}
]

for t in tables: 
    print(t['key'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d6fdb9a81898> in <module>
#       2
#       3 for t in tables:
# ----> 4     print(t['key'])
#
# TypeError: string indices must be integers
